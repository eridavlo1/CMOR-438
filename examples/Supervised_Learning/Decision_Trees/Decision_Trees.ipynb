# %% [markdown]
# ## Decision Tree Classifier Example (Iris Dataset)
# 1. Decision Tree
# Here is demonstrated how to use the DecisionTree module from the rice_ml library to classify data. In this example, the Iris dataset will be used to train, test, and evaluate the model.
# 2. Setup and Data Loading
# Import necessary modules and laod the Iris dataset from scikit-learn.
# The Iris dataset is a small classification dataset that has:
# - Samples: 150
# - Features: 4 features measurements (sepal length, sepal width, petal length, petal width)
# - Classes: 3 types of Iris flowers (Setosa, Versicolor, Virginica)
# Goal: Predict the species of Iris flower based on its four measurements.

# %%
import numpy as np
from sklearn.datasets import load_iris

from rice_ml.supervised_learning import DecisionTreeClassifier
from rice_ml.post_processing import train_test_split, confusion_matrix, accuracy_score

# Loading data
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

print(f"Dataset loaded: {X.shape[0]} samples, {X.shape[1]} features.")
print(f"Classes: {target_names}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       1 import numpy as np
#       2 from sklearn.datasets import load_iris
# ----> 4 from rice_ml.supervised_learning import DecisionTreeClassifier
#       5 from rice_ml.post_processing import train_test_split, confusion_matrix, accuracy_score
#       7 # Loading data
#
# ModuleNotFoundError: No module named 'rice_ml'

# %%
# For this example, we will use 20% for testing (reproducible split)
X_train
